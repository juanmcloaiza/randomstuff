# %%
import sys
for s in sys.path:
    print(s)
    
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
# Out:
# /home/juan/Development/git/randomstuff/1dPyramidArrayBornAgain
# /home/juan/Development/git/randomstuff/1dPyramidArrayBornAgain
# /home/juan/Development/git/ba_build_release/lib
# /home/juan/myNewEnv/lib/python38.zip
# /home/juan/myNewEnv/lib/python3.8
# /home/juan/myNewEnv/lib/python3.8/lib-dynload
# /usr/lib64/python3.8
# /usr/lib/python3.8
#
# /home/juan/myNewEnv/lib/python3.8/site-packages
# /home/juan/myNewEnv/lib/python3.8/site-packages/IPython/extensions
# /home/juan/.ipython

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="inferno", vmin=1e-4, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet")#, vmin=1e-4, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 50.0...
# 	 height = 100.0...
# alpha_i = 0.4...
# 	 height = 50.0...
# 	 height = 100.0...

# %%
#%run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-5, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-5, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-5, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet")#, vmin=1e-5, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...

# %%
#%run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet")#, vmin=1e-5, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 1.0...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 1.0...
# 	 height = 25.0...
# 	 height = 50.0...
# 	 height = 100.0...
# 	 height = 200.0...

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 30.0...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 30.0...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 200.0...

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 30.0...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 30.0...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 200.0...

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
plt.show()
# Out:
# alpha_i = 0.15...
# 	 height = 30.0...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 30.0...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 200.0...

# %%
#%run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
#plt.show()
plt.savefig("no_direct_beam_correction.pdf")

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
#plt.show()
plt.savefig("with_direct_beam_correction.pdf")
# Out:
# alpha_i = 0.15...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 100...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 100...
# 	 height = 200.0...

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
#plt.show()
plt.savefig("with_direct_beam_correction.pdf")
# Out:
# alpha_i = 0.15...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 100...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 100...
# 	 height = 200.0...

# %%
# %run 1dPyramidArray.py

I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,9))
for i in range(I):
    for j in range(J):
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)

fig.text(0.5, 0.04, 'Detector X bin', ha='center', fontsize=20)
fig.text(0.04, 0.5, 'Detector Y bin', va='center', fontsize=20, rotation='vertical')

        
#plt.show()
plt.savefig("with_direct_beam_correction.pdf")
# Out:
# alpha_i = 0.15...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 100...
# 	 height = 200.0...
# alpha_i = 0.4...
# 	 height = 50.0...
# 	 height = 75.0...
# 	 height = 100...
# 	 height = 200.0...

# %%
I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,7))
for i in range(I):
    for j in range(J):
        axes_limits = ba.get_axes_limits(alpha_height_arr[i][j][0], ba.AxesUnits.DEGREES)
        axes_labels = ba.get_axes_labels(alpha_height_arr[i][j][0], ba.AxesUnits.DEGREES)
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), extent=axes_limits, cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cb = fig.colorbar(im, cax=cbar_ax)
cb.set_label("Intensity", fontsize=20)

fig.text(0.5, 0.04, axes_labels[0], ha='center', fontsize=20)
fig.text(0.04, 0.5, axes_labels[1], va='center', fontsize=20, rotation='vertical')

        
#plt.show()
plt.savefig("with_direct_beam_correction.pdf")

# %%
I = len(alpha_height_arr)
J = len(alpha_height_arr[0])
 
fig, ax = plt.subplots(I,J,sharex=True, sharey=True,figsize=(14,7))
for i in range(I):
    for j in range(J):
        axes_limits = ba.get_axes_limits(alpha_height_arr[i][j][0], ba.AxesUnits.QXQY)
        axes_labels = ba.get_axes_labels(alpha_height_arr[i][j][0], ba.AxesUnits.QXQY)
        image = alpha_height_arr[i][j][0].array()
        title = alpha_height_arr[i][j][1]
        im = ax[i,j].imshow(image, norm=matplotlib.colors.LogNorm(), aspect = extent=axes_limits, cmap="jet", vmin=1e-2, vmax=1e4)
        ax[i,j].set_title(title)
        
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cb = fig.colorbar(im, cax=cbar_ax)
cb.set_label("Intensity", fontsize=20)

fig.text(0.5, 0.04, axes_labels[0], ha='center', fontsize=20)
fig.text(0.04, 0.5, axes_labels[1], va='center', fontsize=20, rotation='vertical')

        
#plt.show()
plt.savefig("with_direct_beam_correction.pdf")

# %%
ba.get_axes_labels(alpha_height_arr[i][j][0], ba.AxesUnits.
# Out:
# ['$Q_x \\; $(nm$^{-1}$)', '$Q_y \\; $(nm$^{-1}$)']

# %%
m = plt.imshow(array, norm=norm, extent=axes_limits,
